# %%
import pandas as pd

file = "files_for_lab/csv_files/marketing_customer_analysis.csv"

file = pd.read_csv(file)

file.shape

file.columns = file.columns.str.lower()

file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed: 0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer lifetime value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective to date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location code                  10910 non-null  object
# ...

# %%
file.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months_since_last_claim             0
# months since policy inception       0
# number_of_open_complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
file.state =file.state.fillna("no_data")
file.response = file.response.fillna("no_data")

file =file.rename(columns= {"months since last claim": "months_since_last_claim", "number of open complaints": "number_of_open_complaints", "vehicle class": "vehicle_class", "vehicle size": "vehicle_size", "vehicle type": "vehicle_type" })

# %%
file.months_since_last_claim =file.months_since_last_claim.fillna(0)
file.number_of_open_complaints =file.number_of_open_complaints.fillna(0)

# %%
file.vehicle_class =file.vehicle_class.fillna("no_data")
file.vehicle_size =file.vehicle_size.fillna("no_data")
file.vehicle_type =file.vehicle_type.fillna("no_data")

# %%
file.isna().sum()
# Out:
# unnamed: 0                       0
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months_since_last_claim          0
# months since policy inception    0
# number_of_open_complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %%
file
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877     no_data              6857.519928  no_data
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file.drop('unnamed: 0', axis='columns', inplace=True)

# %%
file

# %%
file =file.rename(columns= {"effective to date": 'effective_to_date'})

# %%
file['effective_to_date_months'] = file.loc[:, 'effective_to_date']

# %%
file
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     no_data              6857.519928  no_data     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
file['effective_to_date'] = pd.to_datetime(file["effective_to_date"], errors="coerce")
     
file["effective_to_date"]
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
file['month'] = file['effective_to_date_months'].dt.month

# %%
jan_feb_mar = file[file['month'] < 4]

print(jan_feb_mar)
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     no_data              6857.519928  no_data     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
def jan_to_mar():
    other_months = file[file["month"]> 4]
    jan_feb_mar = file[file['month'] < 4]

if jan_to_mar:
    print (jan_feb_mar)
else:
    print(ther_months) 

  
jan_to_mar()
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     no_data              6857.519928  no_data     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
file
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     no_data              6857.519928  no_data     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...
